# %%
#!pip install pyglet
#!pip install opencv-python
#!pip install imutils
#!pip install icecream
#!python data/download_d4rl_antmaze_datasets.py
#!pip install mlrose

# %%
import pickle

# %%
with open('antmaze-large-play-v2.pkl', 'rb') as f:
    x = pickle.load(f)

# %%
len(x)
# Out:
# 13499

# %%
x[0]
# Out:
# defaultdict(list,
#             {'observations': array([[ 8.8152772e-01,  1.2716315e+01,  6.6617769e-01, ...,
#                      -7.3606603e-02,  2.4240649e-01, -3.3619337e-02],
#                     [ 8.7970090e-01,  1.2730502e+01,  6.5730637e-01, ...,
#                      -3.1540995e+00, -2.5863395e+00,  3.2699876e+00],
#                     [ 8.8555562e-01,  1.2764140e+01,  5.3268468e-01, ...,
#                      -5.8758032e-01, -4.2516961e+00,  1.1421549e-01],
#                     ...,
#                     [ 2.6781897e+01,  3.1566903e-01,  2.5798884e-01, ...,
#                       5.1393253e-01, -1.2622736e-03, -2.0240909e-01],
#                     [ 2.6782904e+01,  3.1374097e-01,  2.5719103e-01, ...,
#                       1.9353688e-02, -1.6055903e-03,  9.2710018e-02],
#                     [ 2.6784170e+01,  3.1240493e-01,  2.5697917e-01, ...,
#                      -1.9680954e+00,  1.9765212e-03,  1.6673421e-02]], dtype=float32),
# ...

# %%
from collections import defaultdict

dataset=list()

episode_dataset = defaultdict(list)


###
observations = x_first['observations']
actions = x_first['actions']
rewards = x_first['rewards']
next_observations = x_first['next_observations']
terminals = x_first['terminals']

###


episode_dataset['observations'] = observations
episode_dataset['actions'].append(actions)
episode_dataset['rewards'].append(rewards)
episode_dataset['next_observations'].append(next_observations)
episode_dataset['terminals'].append(terminals)

dataset.append(episode_dataset)
dataset.append(episode_dataset)
dataset.append(episode_dataset)
dataset.append(episode_dataset)

# %%
type(x_first['observations'])
# Out:
# numpy.ndarray

# %%
type(dataset[0]['observations'])
# Out:
# numpy.ndarray

# %%
type(dataset[0]['actions'])
# Out:
# list

# %%
x_first
# Out:
# defaultdict(list,
#             {'observations': array([[ 8.8152772e-01,  1.2716315e+01,  6.6617769e-01, ...,
#                      -7.3606603e-02,  2.4240649e-01, -3.3619337e-02],
#                     [ 8.7970090e-01,  1.2730502e+01,  6.5730637e-01, ...,
#                      -3.1540995e+00, -2.5863395e+00,  3.2699876e+00],
#                     [ 8.8555562e-01,  1.2764140e+01,  5.3268468e-01, ...,
#                      -5.8758032e-01, -4.2516961e+00,  1.1421549e-01],
#                     ...,
#                     [ 2.6781897e+01,  3.1566903e-01,  2.5798884e-01, ...,
#                       5.1393253e-01, -1.2622736e-03, -2.0240909e-01],
#                     [ 2.6782904e+01,  3.1374097e-01,  2.5719103e-01, ...,
#                       1.9353688e-02, -1.6055903e-03,  9.2710018e-02],
#                     [ 2.6784170e+01,  3.1240493e-01,  2.5697917e-01, ...,
#                      -1.9680954e+00,  1.9765212e-03,  1.6673421e-02]], dtype=float32),
# ...
